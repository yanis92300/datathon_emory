# %%
cd /fsx1/emory-mammo/tables/
# Out:
# /fsx1/emory-mammo/tables

# %%
ls
# Out:
#  CancerHist_anon.csv*         filtered_magview.csv*
# 'Emory Legend 4-7-21.xlsx'*   filtered_magview_reduced.csv*
#  HormoneHist_anon.csv*        filtered_metadata.csv*
#  MVLexicon.csv*               filtered_metadata_MRI_anon.csv*
#  ProcedureHist_anon.csv*      filtered_metadata_reduced.csv*
#  RiskHist_anon.csv*

# %%
import pandas as pd

source_path = '/fsx1/emory-mammo/tables/filtered_metadata_reduced.csv'
df = pd.read_csv(source_path)
df.head()  # Display the first few rows of the dataframe
# Out:
# /tmp/ipykernel_8664/1297772430.py:4: DtypeWarning: Columns (26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(source_path)
#    empi_anon          acc_anon  cohort_num      study_date_anon  \
# 0   66685715  7208547536889815           1  2017-05-15 00:00:00
# 1   30864920  7774461277054123           1  2019-08-05 00:00:00
# 2   30864920  7774461277054123           1  2019-08-05 00:00:00
# 3   30864920  7774461277054123           1  2019-08-05 00:00:00
# 4   30864920  7774461277054123           1  2019-08-05 00:00:00
#
#                            StudyDescription SeriesDescription FinalImageType  \
# 0                    MG Screening Bilateral             L MLO             2D
# 1  MG Screen Bilat w/Tomo/CAD Stnd Protocol             R MLO             2D
# 2  MG Screen Bilat w/Tomo/CAD Stnd Protocol      R MLO C-View          cview
# 3  MG Screen Bilat w/Tomo/CAD Stnd Protocol              R CC             2D
# 4  MG Screen Bilat w/Tomo/CAD Stnd Protocol       R CC C-View          cview
#
#   ImageLateralityFinal ViewPosition  spot_mag  ...   ProtocolName  \
# 0                    L          MLO       NaN  ...          L MLO
# 1                    R          MLO       NaN  ...  R MLO ComboHD
# 2                    R          MLO       NaN  ...  R MLO ComboHD
# 3                    R           CC       NaN  ...   R CC ComboHD
# 4                    R           CC       NaN  ...   R CC ComboHD
#
#    SeriesNumber SeriesTime           StudyID WindowCenter WindowWidth  \
# 0      71100000    93624.0  MG Screening Dig       2047.0      4096.0
# 1      71300000   135938.0   MG Screen Bilat       2047.0      4096.0
# 2      71300000   135938.0   MG Screen Bilat        540.0       580.0
# 3      71300000   135833.0   MG Screen Bilat       2047.0      4096.0
# 4      71300000   135833.0   MG Screen Bilat        540.0       580.0
#
#   has_pix_array  category VOILUTFunction  WindowCenterWidthExplanation
# 0         False  no image            NaN                           NaN
# 1         False  no image            NaN                           NaN
# 2         False  no image            NaN                           NaN
# 3         False  no image            NaN                           NaN
# 4         False  no image            NaN                           NaN
#
# [5 rows x 28 columns]

# %%
# List the column names
column_names = df.columns.tolist()

# Display the column names
print(column_names)
# Out:
# ['empi_anon', 'acc_anon', 'cohort_num', 'study_date_anon', 'StudyDescription', 'SeriesDescription', 'FinalImageType', 'ImageLateralityFinal', 'ViewPosition', 'spot_mag', 'anon_dicom_path', 'num_roi', 'PNG_ROI_coords', 'SSC_match_level', 'ROI_match_level', 'Manufacturer', 'ManufacturerModelName', 'PatientSex', 'ProtocolName', 'SeriesNumber', 'SeriesTime', 'StudyID', 'WindowCenter', 'WindowWidth', 'has_pix_array', 'category', 'VOILUTFunction', 'WindowCenterWidthExplanation']
